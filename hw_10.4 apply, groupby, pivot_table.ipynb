# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd
df = pd.read_csv('/content/supermarket_sales.csv')

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby('Branch')['gross income'].sum().sort_values(ascending=False)
# Out:
# Branch
# C    5265.1765
# A    5057.1605
# B    5057.0320
# Name: gross income, dtype: float64

# %%
df.groupby('Branch')['gross income'].sum().sort_values(ascending=False).head(1)
# Out:
# Branch
# C    5265.1765
# Name: gross income, dtype: float64

# %%
df.groupby('Branch')['gross income'].sum().sort_values(ascending=False).agg('max')
# Out:
# 5265.1765

# %% [markdown]
# Найприбутковішим є філіал супермаркету С.

# %% [markdown]
# 2. В якому місті знаходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df.groupby(['Branch', 'City'])['gross income'].sum().sort_values(ascending=False)
# Out:
# Branch  City
# C       Naypyitaw    5265.1765
# A       Yangon       5057.1605
# B       Mandalay     5057.0320
# Name: gross income, dtype: float64

# %%
df.groupby(['Branch', 'City'])['gross income'].sum().sort_values(ascending=False).head(1)
# Out:
# Branch  City
# C       Naypyitaw    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# Філіал з найвищим прибутком знаходиться у місті Naypyitaw.

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = pd.pivot_table(df, index='Branch', columns='Product line', values='Invoice ID', aggfunc='count')
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category['Electronic accessories'].sort_values(ascending=False).head(1)
# Out:
# Branch
# A    60
# Name: Electronic accessories, dtype: int64

# %% [markdown]
# Найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" в філії магазину А.

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# 4. Скільки покупок в кожній філії здійснено клієнтом з карткою магазину та без картки магазину?

# %%
cust_type_by_branch = pd.pivot_table(df, index='Customer type', columns='Branch', values='Invoice ID', aggfunc='count')
cust_type_by_branch
# Out:
# Branch           A    B    C
# Customer type
# Member         167  165  169
# Normal         173  167  159

# %% [markdown]
# У філії С кількість покупок зроблених з картою магазину більша, ніж без карти. Тоді як у філіях А та В навпаки.
#
# Це допоможе з'ясувати в якому магазині (філія С) засоби залучення клієнтів до отримання картки магазину мають кращий результат і поширити їх на інші магазини (філії А та В) мережі для підняття залученості покупців до програми лояльності.

# %% [markdown]
# 5. Вивести кількість покупок за містом та способом оплати.

# %%
payment_by_city = pd.pivot_table(df, index='Payment', columns=['City'], values='Invoice ID', aggfunc= 'count')
payment_by_city
# Out:
# City         Mandalay  Naypyitaw  Yangon
# Payment
# Cash              110        124     110
# Credit card       109         98     104
# Ewallet           113        106     126

# %% [markdown]
# Це допоможе проаналізувати популярність способів оплати в кожному місті для подальшого розширення можливості оплати популярним способом.
#
# Наприклад, в місті Naypyitaw популярний готівковий спосіб оплати -> збільшити кількість кас з готівковим способом оплати. В місті Yangon популярний спосіб оплати Ewallet -> збільшити кількість кас з способом оплати Ewallet.

# %% [markdown]
# 6. Вивести кількість оцінок та середній рейтинг за категорією та статтю покупця.

# %%
rating_by_category_gender = pd.pivot_table(df, index='Product line', columns='Gender', values='Rating', aggfunc= ['count', 'mean'])
rating_by_category_gender
# Out:
#                         count           mean
# Gender                 Female Male    Female      Male
# Product line
# Electronic accessories     84   86  6.786905  7.059302
# Fashion accessories        96   82  7.120833  6.921951
# Food and beverages         90   84  7.203333  7.016667
# Health and beauty          64   88  7.146875  6.898864
# Home and lifestyle         79   81  6.763291  6.909877
# Sports and travel          88   78  6.767045  7.084615

# %% [markdown]
# Кількість відгуків від жінок більша у категоріях: Fashion accessories, Food and beverages. Кількість відгуків від чоловіків більша у категоріях: Health and beauty, Electronic accessories.
#
# Це допоможе з'ясувати в яких магазинах варто розширити асортимент та покращити сервіс для залучення покупців (протилежної статі) та збільшення обсягу продажів.
